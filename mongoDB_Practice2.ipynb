# %%
# !pip install pymongo
# !pip install dnspython

# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import urllib

import ssl
username = "mugeshk403"
password = "Lonelyrider16ce133"

encoded_username = urllib.parse.quote_plus(username)
encoded_password = urllib.parse.quote_plus(password)

ssl_context = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE

uri = f"mongodb+srv://{encoded_username}:{encoded_password}@cluster0.iabwlcx.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"

client = MongoClient(uri, server_api=ServerApi('1'), tz_aware=False, connect=True)

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
assignment=client["sample_airbnb"]["listingsAndReviews"]

# %%
list(assignment.find().limit(1))
# Out:
# [{'_id': '1001265',
#   'listing_url': 'https://www.airbnb.com/rooms/1001265',
#   'name': 'Ocean View Waikiki Marina w/prkg',
#   'summary': "A short distance from Honolulu's billion dollar mall, and the same distance to Waikiki. Parking included. A great location that work perfectly for business, education, or simple visit. Experience Yacht Harbor views and 5 Star Hilton Hawaiian Village.",
#   'space': 'Great studio located on Ala Moana across the street from Yacht Harbor and near Ala Moana Shopping Center. Studio kitchette, parking, wifi, TV, A/C. Amenities include pool, hot tub and tennis. Sweet ocean views with nice ocean breezes.',
# ...

# %%
# Projecting amenities,price alone from the set

# %%
list(assignment.find({},{"amenities":1,"price":1}).limit(1))
# Out:
# [{'_id': '1001265',
#   'amenities': ['TV',
#    'Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Pool',
#    'Kitchen',
#    'Free parking on premises',
#    'Elevator',
#    'Hot tub',
#    'Washer',
#    'Dryer',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Ethernet connection',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'BBQ grill',
#    'Garden or backyard',
#    'Well-lit path to entrance',
#    'Disabled parking spot',
#    'Step-free access',
#    'Wide clearance to bed',
#    'Step-free access'],
#   'price': Decimal128('115.00')}]

# %%
# What is the min and max price for each cities

# %%
ques1=[{"$group":{"_id":{"property type":"$property_type",
                         "country":"$address.country"},"max Price":{"$max":"$price",},"min price":{"$min":"$price"}}
                  },{"$sort":{"max Price":-1,"min price":-1}}]

# %%
q1_df=list(assignment.aggregate(ques1))

# %%
import pandas as pd
pd.DataFrame(q1_df)
# Out:
#                                                    _id max Price min price
# 0    {'property type': 'Apartment', 'country': 'Tur...  48842.00     26.00
# 1    {'property type': 'Serviced apartment', 'count...  11681.00    283.00
# 2    {'property type': 'Condominium', 'country': 'H...  11681.00    220.00
# 3    {'property type': 'Apartment', 'country': 'Bra...  11190.00     30.00
# 4    {'property type': 'Bed and breakfast', 'countr...  10001.00    173.00
# ..                                                 ...       ...       ...
# 154   {'property type': 'Hostel', 'country': 'Canada'}     39.00     31.00
# 155      {'property type': 'Boat', 'country': 'Spain'}     35.00     35.00
# 156  {'property type': 'Campsite', 'country': 'Unit...     25.00     25.00
# 157  {'property type': 'Bungalow', 'country': 'Cana...     24.00     24.00
# 158  {'property type': 'Tiny house', 'country': 'Au...     16.00     16.00
#
# [159 rows x 3 columns]

# %%
# what type of properties have more amenities        |            Ans:Apartment

# %%
ques2=[{"$group":{"_id":{"property type":"$property_type"},"Count of amenities":{"$sum":1}}},{"$sort":{"Count of amenities":-1}}]

# %%
q2_df=list(assignment.aggregate(ques2))
pd.DataFrame(q2_df)
# Out:
#                                             _id  Count of amenities
# 0                {'property type': 'Apartment'}                3626
# 1                    {'property type': 'House'}                 606
# 2              {'property type': 'Condominium'}                 399
# 3       {'property type': 'Serviced apartment'}                 185
# 4                     {'property type': 'Loft'}                 142
# 5                {'property type': 'Townhouse'}                 108
# 6              {'property type': 'Guest suite'}                  81
# 7        {'property type': 'Bed and breakfast'}                  69
# 8           {'property type': 'Boutique hotel'}                  53
# 9               {'property type': 'Guesthouse'}                  50
# 10                  {'property type': 'Hostel'}                  34
# 11                   {'property type': 'Villa'}                  32
# 12                   {'property type': 'Hotel'}                  26
# ...

# %%
#country wise property type distribution                                                 """,{"$sort":{"Property Type Count":-1}}"""

# %%
ques3=[{"$group":{"_id":{"country":"$address.country","Property Type":"$property_type"},"Property Type Count ":{"$sum":1}}}]
q3_df=list(assignment.aggregate(ques3))
pd.DataFrame(q3_df)
# Out:
#                                                    _id  Property Type Count
# 0    {'country': 'United States', 'Property Type': ...                    31
# 1    {'country': 'Portugal', 'Property Type': 'Gues...                    11
# 2    {'country': 'Australia', 'Property Type': 'Vil...                     7
# 3    {'country': 'Hong Kong', 'Property Type': 'Ser...                    29
# 4    {'country': 'Australia', 'Property Type': 'Tra...                     1
# ..                                                 ...                   ...
# 154  {'country': 'Australia', 'Property Type': 'Cab...                     8
# 155  {'country': 'Hong Kong', 'Property Type': 'Hou...                     1
# 156  {'country': 'Hong Kong', 'Property Type': 'Gue...                     9
# 157  {'country': 'Portugal', 'Property Type': 'Cond...                    13
# 158  {'country': 'Portugal', 'Property Type': 'Apar...                   383
#
# [159 rows x 2 columns]
