# %%
# !pip install pymongo
# !pip install dnspython
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 9.9 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import urllib

import ssl
username = "mugeshk403"
password = "Lonelyrider16ce133"

encoded_username = urllib.parse.quote_plus(username)
encoded_password = urllib.parse.quote_plus(password)

ssl_context = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE

uri = f"mongodb+srv://{encoded_username}:{encoded_password}@cluster0.iabwlcx.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"

client = MongoClient(uri, server_api=ServerApi('1'), tz_aware=False, connect=True)

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['sample_airbnb']
collection = db['listingsAndReviews']

# %%
query = {
    'room_type': 'Private room',  # Example query: Find private rooms
    'accommodates': {'$gte': 2},  # Example query: Accommodates 2 or more guests
    'price': {'$lte': 100},       # Example query: Priced at $100 or less
}

# Perform the query and store the result
result = collection.find(query).limit(5)

# %%
for document in result:
    print(document)
# Out:
# {'_id': '10138784', 'listing_url': 'https://www.airbnb.com/rooms/10138784', 'name': 'Room Close to LGA and 35 mins to Times Square', 'summary': 'A private small bedroom in a 2 BR 1BA apartment. There’s no living area as I converted to live in. The location is 2 minutes to Q33 bus stop, 5 minutes to 7 train station ( which directly takes you to Times Square in 35-40 minutes ).', 'space': 'The bedroom has a queen bed, a closet, a mini fridge, outlets, USB ports, wifi, and AC.', 'description': 'A private small bedroom in a 2 BR 1BA apartment. There’s no living area as I converted to live in. The location is 2 minutes to Q33 bus stop, 5 minutes to 7 train station ( which directly takes you to Times Square in 35-40 minutes ). The bedroom has a queen bed, a closet, a mini fridge, outlets, USB ports, wifi, and AC. Kitchen is not provided to use. Guest have access to the bedroom and bathroom only. This apartment has my husband and me. This place also has a chinchilla and a French Bulldog. We
# ...

# %%
db = client['myfirst_nosqldb']

# %%
# Insert a document into a collection in the database
collection = db['firstcollection']  # Specify the collection name
document = {
    'name': 'John Doe',
    'email': 'johndoe@example.com',
    'age': 30
}

# Insert the document into the collection, which creates the database if it doesn't exist
insert_result = collection.insert_one(document)

# Print the inserted document's ID
print(f"Inserted document ID: {insert_result.inserted_id}")
# Out:
# Inserted document ID: 65166a462762afd3133c89eb

# %%
newdb=client["customer_db"]
new_customer=newdb["customer_details"]

# %%
data_to_insert={"Customer_name":"MUGESHKUMAR.D",
                "Customer_ID":"16ce133",
                "Age":25,
                "Purchased_item": "Kitkat",
                "Purchased_Date": "2023-10-3" ,
                "College":{"Department":"Civil Engineering",
                           "Specialization":"Geotechnical Engineering",
                           "YOP":2020}}
data=new_customer.insert_one(data_to_insert) # insertion of one data
ans= new_customer.find()

# %%
many_to_insert=[{"Customer_name":"PRAVEEN.V",
                "Customer_ID":"16ce143",
                "Age":25,
                "Purchased_item": "SILK",
                "Purchased_Date": "2023-7-21" ,
                "College":{"Department":"Civil Engineering",
                           "Specialization":"Construction Engineering",
                           "YOP":2020}},
                {"Customer_name":"PRADEEP.S",
                "Customer_ID":"16ce141",
                "Age":25,
                "Purchased_item": "Milkybar",
                "Purchased_Date": "2023-9-4" ,
                "College":{"Department":"Civil Engineering",
                           "Specialization":"Environmental Engineering",
                           "YOP":2020}},
                {"Customer_name":"Kishore.R",
                "Customer_ID":"16ce127",
                "Age":25,
                "Purchased_item": "Majboos",
                "Purchased_Date": "2023-10-1" ,
                "College":{"Department":"Civil Engineering",
                           "Specialization":"Transportation Engineering",
                           "YOP":2020}},
                {"Customer_name":"Deepak.M",
                "Customer_ID":"16ce110",
                "Age":25,
                "Purchased_item": "Kitkat",
                "Purchased_Date": "2023-12-17" ,
                "College":{"Department":"Civil Engineering",
                           "Specialization":"Geotechnical Engineering",
                           "YOP":2020}}]
data=new_customer.insert_many(many_to_insert)# insertion of many data
ans=new_customer.find()

# %%
for i in ans:
  print(i)
# Out:
# {'_id': ObjectId('651bd691823fbb2819499982'), 'Customer_name': 'MUGESHKUMAR.D', 'Customer_ID': '16ce133', 'Age': 25, 'Purchased_item': 'Kitkat', 'Purchased_Date': '2023-10-3', 'College': {'Department': 'Civil Engineering', 'Specialization': 'Geotechnical Engineering', 'YOP': 2020}}
# {'_id': ObjectId('651be489823fbb2819499985'), 'Customer_name': 'PRAVEEN.V', 'Customer_ID': '16ce143', 'Age': 25, 'Purchased_item': 'SILK', 'Purchased_Date': '2023-7-21', 'College': {'Department': 'Civil Engineering', 'Specialization': 'Construction Engineering', 'YOP': 2020}}
# {'_id': ObjectId('651be489823fbb2819499986'), 'Customer_name': 'PRADEEP.S', 'Customer_ID': '16ce141', 'Age': 25, 'Purchased_item': 'Milkybar', 'Purchased_Date': '2023-9-4', 'College': {'Department': 'Civil Engineering', 'Specialization': 'Environmental Engineering', 'YOP': 2020}}
# ...

# %%
list(new_customer.find({"Customer_name":"Deepak.M"})) # for retrieval
# Out:
# [{'_id': ObjectId('651be489823fbb2819499988'),
#   'Customer_name': 'Deepak.M',
#   'Customer_ID': '16ce110',
#   'Age': 25,
#   'Purchased_item': 'Kitkat',
#   'Purchased_Date': '2023-12-17',
#   'College': {'Department': 'Civil Engineering',
#    'Specialization': 'Geotechnical Engineering',
#    'YOP': 2020}}]

# %%
ret=client["sample_supplies"]
supplies=ret["sales"]

# %%
list(supplies.find().limit(1))
# Out:
# [{'_id': ObjectId('5bd761dcae323e45a93ccfe8'),
#   'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#   'items': [{'name': 'printer paper',
#     'tags': ['office', 'stationary'],
#     'price': Decimal128('40.01'),
#     'quantity': 2},
#    {'name': 'notepad',
#     'tags': ['office', 'writing', 'school'],
#     'price': Decimal128('35.29'),
#     'quantity': 2},
#    {'name': 'pens',
#     'tags': ['writing', 'office', 'school', 'stationary'],
#     'price': Decimal128('56.12'),
#     'quantity': 5},
#    {'name': 'backpack',
#     'tags': ['school', 'travel', 'kids'],
#     'price': Decimal128('77.71'),
#     'quantity': 2},
#    {'name': 'notepad',
#     'tags': ['office', 'writing', 'school'],
#     'price': Decimal128('18.47'),
#     'quantity': 2},
#    {'name': 'envelopes',
#     'tags': ['stationary', 'office', 'general'],
#     'price': Decimal128('19.95'),
#     'quantity': 8},
#    {'name': 'envelopes',
#     'tags': ['stationary', 'office', 'general'],
# ...

# %%
 result=list(supplies.find({"storeLocation":"Denver"}))
 for i in  result :
      print(i)
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccfe8'), 'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000), 'items': [{'name': 'printer paper', 'tags': ['office', 'stationary'], 'price': Decimal128('40.01'), 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': Decimal128('35.29'), 'quantity': 2}, {'name': 'pens', 'tags': ['writing', 'office', 'school', 'stationary'], 'price': Decimal128('56.12'), 'quantity': 5}, {'name': 'backpack', 'tags': ['school', 'travel', 'kids'], 'price': Decimal128('77.71'), 'quantity': 2}, {'name': 'notepad', 'tags': ['office', 'writing', 'school'], 'price': Decimal128('18.47'), 'quantity': 2}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': Decimal128('19.95'), 'quantity': 8}, {'name': 'envelopes', 'tags': ['stationary', 'office', 'general'], 'price': Decimal128('8.08'), 'quantity': 3}, {'name': 'binder', 'tags': ['school', 'general', 'organization'], 'price': Decimal128('14.16'), 'quantity': 3}]
# ...

# %%
print(len(result))
# Out:
# 1549

# %%
len(list(supplies.find({"$and":[{"items.name":"printer paper"},{"items.quantity":{"$gt":5}}]})))
# Out:
# 1893

# %%
len(list(supplies.find({"$and":[
 {"$and":[{"items.name":"printer paper"},{"items.quantity":{"$gt":5}}]},
 {"$or":[{"items.name":"notepad"},{"purchaseMethod":"Online"}]}]
                    })))
# Out:
# 1740

# %%
from datetime import datetime
setdate=datetime(2015,3,23,21,6,49)

# %%
list(supplies.distinct("items.name"))
# Out:
# ['backpack',
#  'binder',
#  'envelopes',
#  'laptop',
#  'notepad',
#  'pens',
#  'printer paper']

# %%
list(supplies.find({"saleDate":{"$gt":setdate}}))
# Out:
# [{'_id': ObjectId('5bd761dcae323e45a93ccfe8'),
#   'saleDate': datetime.datetime(2015, 3, 23, 21, 6, 49, 506000),
#   'items': [{'name': 'printer paper',
#     'tags': ['office', 'stationary'],
#     'price': Decimal128('40.01'),
#     'quantity': 2},
#    {'name': 'notepad',
#     'tags': ['office', 'writing', 'school'],
#     'price': Decimal128('35.29'),
#     'quantity': 2},
#    {'name': 'pens',
#     'tags': ['writing', 'office', 'school', 'stationary'],
#     'price': Decimal128('56.12'),
#     'quantity': 5},
#    {'name': 'backpack',
#     'tags': ['school', 'travel', 'kids'],
#     'price': Decimal128('77.71'),
#     'quantity': 2},
#    {'name': 'notepad',
#     'tags': ['office', 'writing', 'school'],
#     'price': Decimal128('18.47'),
#     'quantity': 2},
#    {'name': 'envelopes',
#     'tags': ['stationary', 'office', 'general'],
#     'price': Decimal128('19.95'),
#     'quantity': 8},
#    {'name': 'envelopes',
#     'tags': ['stationary', 'office', 'general'],
# ...

# %%
len(list(supplies.find({"saleDate":{"$eq":setdate}})))
# Out:
# 0

# %%
to_filter=supplies.find({"items.name":"printer paper"})
filtered_list=[i["items"] for i in to_filter ]

# %%
count=len(filtered_list)
count
# Out:
# 2246

# %%
# UPDATING MY NAME TO SOMEOTHER NAME AND DELETE DEEPAK
new_customer.update_one({"Customer_name":"MUGESHKUMAR.D"},{"$set":{"Customer_name":"ASHWIN"}})

# %%
# DELETE operation
new_customer.delete_one({"Customer_name":"Deepak.M"})
